# %%
Workflow Diagram:
    
Business Understanding
        │
        ▼
Collect Two CSV Files (Luxe.csv & AirBnB.csv)
        │
        ▼
Compare Column Structure
        │
        ▼
Concatenate Datasets
        │
        ▼
Explore Combined Dataset
        │
        ▼
Clean Data
        │
        ▼
Feature Engineering
        │
        ▼
Exploratory Data Analysis
        │
        ▼
Hypothesis Testing
        │
        ▼
Business Insights
        │
        ▼
Recommendations

# %%
1. Business Understanding

Define:

Business problem
Background
Goal
Research questions
Hypotheses

2. Data Collection

Datasets:

airnb.csv
airnb_luxe.csv
airnb_desert.csv

Document:

Number of files
Number of observations
Variables
Source

3. Data Integration
This is where you combine the datasets.

Step 1
Load all CSV files.

Step 2
Compare the columns.

4. Data Understanding

Explore the combined dataset.

Examples
Shape
Columns
Data types
Missing values
Duplicate rows
Summary statistics

5. Data Cleaning

Examples
Remove duplicates.
Handle missing ratings.
Convert prices into numeric values.
Convert beds into integers.
Convert ratings into numeric values.
Standardize property names.

6. Feature Engineering

This is where your project becomes more interesting.
From Title, extract:
Country
City
Property type

From Detail, extract amenities such as:
Pool
Wifi
Hot tub
Kitchen
Beachfront
Fireplace
Parking
Pet friendly

7. Exploratory Data Analysis

Examples
Distribution of ratings.
Distribution of prices.
Top amenities.
Average ratings by property type.
Average ratings by country.
Price versus rating.
Beds versus rating.
Missing amenities in poorly rated listings.

8. Statistical Analysis 
Test your hypotheses.

9. Insights

10. Recommendations

# %%
Project File Strtucture

airbnb_guest_satisfaction/
│
├── data/
│   ├── raw/
│   │   ├── airnb.csv
│   │   ├── airnb_luxe.csv
│   │   └── airnb_desert.csv
│   │
│   └── processed/clean 
│       └── airbnb_combined.csv
│
├── notebooks/
│   ├── 01_business_understanding.ipynb
│   ├── 02_data_cleaning.ipynb
│   ├── 03_feature_engineering.ipynb
│   ├── 04_exploratory_data_analysis.ipynb
│   ├── 05_hypothesis_testing.ipynb
│   └── 06_conclusions_and_recommendations.ipynb
│
├── src/
│   ├── data_cleaning.py
│   ├── feature_engineering.py
│   ├── visualization.py
│   └── statistics.py
│
├── outputs/
│   ├── figures/
│   ├── tables/
│   └── presentation/
│
├── README.md
├── requirements.txt
└── .gitignore
