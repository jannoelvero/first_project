# %%
import sys
import os

print("Python:", sys.executable)
print("Working folder:", os.getcwd())
# Out:
# Python: /Users/jannoelvero/Documents/Ironhack/week_4/first_project/.venv/bin/python
# Working folder: /Users/jannoelvero/Documents/Ironhack/week_4/first_project/notebooks
